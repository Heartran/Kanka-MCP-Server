# %% [markdown]
# # Avvio server con auto-restart
#
# Questo notebook replica la logica di `run.ps1`.
# Esegue il server Node, avvia `tailscale serve` e poi controlla periodicamente aggiornamenti su Git per riavviare se necessario.

# %% [markdown]
# # Installazione
# ## Clona la repository

# %%
# !git clone https://github.com/Heartran/Kanka-MCP-Server.git
# Out:
# Cloning into 'Kanka-MCP-Server'...
# remote: Enumerating objects: 192, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 192 (delta 30), reused 36 (delta 13), pack-reused 123 (from 1)
# Receiving objects: 100% (192/192), 79.54 KiB | 5.30 MiB/s, done.
# Resolving deltas: 100% (102/102), done.

# %% [markdown]
# ## Installa Node.js
# ### Verifica se è già installato

# %%
# !node --version
# !npm --version
# Out:
# v20.19.0
# 10.8.2

# %% [markdown]
# ### Installa le dipendenze

# %%
# !npm install
# Out:
# ⠙npm error code ENOENT
# ⠙npm error syscall open
# ⠙npm error path /content/package.json
# ⠙npm error errno -2
# ⠙npm error enoent Could not read package.json: Error: ENOENT: no such file or directory, open '/content/package.json'
# ⠙npm error enoent This is related to npm not being able to find a file.
# npm error enoent
# ⠙npm error A complete log of this run can be found in: /root/.npm/_logs/2026-01-29T01_02_22_729Z-debug-0.log
# ⠙

# %% [markdown]
# # Avvia il server

# %%
# !node index.js
# Out:
# node:internal/modules/cjs/loader:1215
#   throw err;
#   ^
#
# Error: Cannot find module '/content/index.js'
#     at Module._resolveFilename (node:internal/modules/cjs/loader:1212:15)
#     at Module._load (node:internal/modules/cjs/loader:1043:27)
#     at Function.executeUserEntryPoint [as runMain] (node:internal/modules/run_main:164:12)
#     at node:internal/main/run_main_module:28:49 {
#   code: 'MODULE_NOT_FOUND',
#   requireStack: []
# }
#
# Node.js v20.19.0
