# %% [markdown]
# <a href="https://colab.research.google.com/github/Heartran/Kanka-MCP-Server/blob/main/Kanka%20MCP%20Server.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Avvio server con auto-restart
#
# Questo notebook replica la logica di `run.ps1`.
# Esegue il server Node, avvia `tailscale serve` e poi controlla periodicamente aggiornamenti su Git per riavviare se necessario.

# %% [markdown]
# # Installazione
# ## Clona la repository

# %%
# !git clone https://github.com/Heartran/Kanka-MCP-Server.git
# Out:
# Cloning into 'Kanka-MCP-Server'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 195 (delta 31), reused 39 (delta 14), pack-reused 123 (from 1)
# Receiving objects: 100% (195/195), 81.22 KiB | 1.25 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %% [markdown]
# ## Installa Node.js
# ### Verifica se è già installato

# %%
# !node --version
# !npm --version
# Out:
# v20.19.0
# 10.8.2

# %% [markdown]
# ### Installa le dipendenze

# %%
# !cd /content/Kanka-MCP-Server && npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧
# added 128 packages, and audited 129 packages in 4s
# ⠧
# ⠧32 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧
# 3 high severity vulnerabilities
#
# To address all issues, run:
#   npm audit fix
#
# Run `npm audit` for details.
# ⠧

# %% [markdown]
# # Avvia il server

# %%
# !cd /content/Kanka-MCP-Server && node index.js
# Out:
# ^C
